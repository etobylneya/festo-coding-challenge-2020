# %% [markdown]
# # 22 (3.4) Mystery Man, Imagine

# %% [markdown]
# "The code is hidden in the image on the page that does not exist." says the puzzle.

# %% [markdown]
# the page that doesn't exist is the one that yields **Error 404**

# %% [markdown]
# So let's just paste 404 to the challenge url and then open it to see if there is anything there. https://coding-challenge.festo.com/404

# %% [markdown]
# There is a picture in the background, lets take a look at it. We can open the inspector of the web browser and download the image from there:

# %% [markdown]
# right click -> inspector -> 'sources' tab -> 'images' folder -> right click on 'cybersecurity.png' -> 'open in new tab' -> right click -> save as

# %% [markdown]
# ![cybersecurity.png](attachment:cybersecurity.png)

# %% [markdown]
# If you take a closer look, you will see a text in the background saying <br>nice try <br>nothing here <br>have a look at <br>FFT?

# %% [markdown]
# FFT stands for Fast Fourier Transform. I found the following web page for FFT: http://bigwww.epfl.ch/demo/ip/demos/FFT/ and the following result:

# %% [markdown]
# ![cybersec_fft.png](attachment:cybersec_fft.png)

# %% [markdown]
# There is a text on the right image that says 'Top!' <br>That's the code!

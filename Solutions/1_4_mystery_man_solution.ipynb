# %% [markdown]
# # 10 (1.4) Mystery Man, Follow the Trace

# %% [markdown]
# If you read the blog of the intern, you will know he received a screen, mouse and keyboard, notebook and a pen from Festo. There are pictures of every item but the screen. If you click the screen link it leads you to a 'Never Gonna Give You Up by Rick Astley'video on Youtube. But why is there no picture of the screen? There must be something important about that screen since there is no picture of it.
# <br>
# A link to mouse and keyborad looks like this https://coding-challenge.festo.com/blog/images/mouse_and_keyboard.jpg
# <br>
# So if I paste screen.jpeg instead of mouse_and_keyboard.jpeg in the url (https://coding-challenge.festo.com/blog/images/screen.jpg), we will get the picture of the screen, here it is:

# %% [markdown]
# ![screen.jpg](attachment:screen.jpg)

# %% [markdown]
# There is a sticky note on the right bottom corner of the screen with a github account. if you open the mouse and keyboard picture you will get the full name of the github account

# %% [markdown]
# ![mouse_and_keyboard.jpg](attachment:mouse_and_keyboard.jpg)

# %% [markdown]
# Account name is fin-der-lohn. https://github.com/fin-der-lohn, you will find the code there, it's **1337potato**

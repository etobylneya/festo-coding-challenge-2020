# %% [markdown]
# # 13 (2.1) No More 2020, Maintenance Man

# %%
rooms = []
number_int = 1
while len(rooms) < 1000000:
    
    number = str(number_int)
    rooms.append(number)
    cntr_2 = number.count('2')
    cntr_0 = number.count('0')
    
    if (cntr_2 >= 2) and (cntr_0 >= 2):
        cntr_20 = 0
        first_two = number.find('2')
        first_zero = number[first_two:].find('0')
        if (first_zero + first_two > first_two):

            first_zero += first_two
            second_two = number[first_zero:].find('2')
            if second_two != -1:
                second_zero = number[second_two + first_zero:].find('0')
                if second_zero != -1:
                    second_two += first_zero
                    second_zero += second_two
                    if second_zero > second_two:

                        rooms.pop()
    number_int += 1 
print(rooms[-1])
# Out:
# 1001270
